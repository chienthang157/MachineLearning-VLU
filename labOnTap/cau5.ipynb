# %%
# Import các thư viện cần thiết
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
# Bước 1: Tải tập dữ liệu Breast Cancer
cancer = load_breast_cancer()
X = cancer.data  # Dữ liệu đầu vào
y = cancer.target  # Nhãn

# Bước 2: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra với tỷ lệ 75:25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Bước 3: Huấn luyện mô hình Cây Quyết Định
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

# Dự đoán trên tập kiểm tra
y_pred_dt = dt_model.predict(X_test)

# Tính toán độ chính xác
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f"Độ chính xác của mô hình Cây Quyết Định: {accuracy_dt:.2f}")
# Out:
# Độ chính xác của mô hình Cây Quyết Định: 0.95

# %%
# Bước 4: Xuất ra hình ảnh của cây quyết định
plt.figure(figsize=(15, 10))
tree.plot_tree(dt_model, filled=True, feature_names=cancer.feature_names, class_names=cancer.target_names)
plt.title("Cây Quyết Định cho Dữ liệu Ung thư Vú")
plt.show()
